# %%
import numpy as np 
import pandas as pd

# %%
data=pd.read_csv('customer.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8049 entries, 0 to 8048
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    8000 non-null   object
#  1   Customer_Name  8000 non-null   object
#  2   DOB            8000 non-null   object
#  3   City           8000 non-null   object
#  4   State          8000 non-null   object
#  5   Income         8000 non-null   float64
#  6   Credit_Score   8000 non-null   float64
#  7   Gender         6415 non-null   object
#  8   Phone          8000 non-null   float64
#  9   Email          8000 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 629.0+ KB

# %%
dup=data.duplicated()

# %%
print(dup)
# Out:
# 48

# %%
df_dp=pd.DataFrame(dup)

# %%
data=data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8001 entries, 0 to 8048
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    8000 non-null   object
#  1   Customer_Name  8000 non-null   object
#  2   DOB            8000 non-null   object
#  3   City           8000 non-null   object
#  4   State          8000 non-null   object
#  5   Income         8000 non-null   float64
#  6   Credit_Score   8000 non-null   float64
#  7   Gender         8001 non-null   object
#  8   Phone          8000 non-null   float64
#  9   Email          8000 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 687.6+ KB

# %%
data=data.groupby('Customer_ID')['Income'].max().reset_index()

# %%
print(income_data)
# Out:
#      Customer_ID     Income
# 0       CUST1000  2150984.0
# 1       CUST1001  4467228.0
# 2       CUST1003  3508627.0
# 3       CUST1004  3740188.0
# 4       CUST1005  1605330.0
# ...          ...        ...
# 5264    CUST9993  2610237.0
# 5265    CUST9995  2282197.0
# 5266    CUST9996  2005830.0
# 5267    CUST9998  3544411.0
# 5268    CUST9999  2105291.0
#
# [5269 rows x 2 columns]

# %%
data.to_csv('E:\Data Analysis\Project\Loan\customer.csv',index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7984\425017714.py:1: SyntaxWarning: invalid escape sequence '\D'
#   data.to_csv('E:\Data Analysis\Project\Loan\customer.csv',index=False)

# %%
credit_data.to_csv('E:\Data Analysis\Project\Loan\credit_data.csv',index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7984\3864462500.py:1: SyntaxWarning: invalid escape sequence '\D'
#   credit_data.to_csv('E:\Data Analysis\Project\Loan\credit_data.csv',index=False)

# %%
cst=data['Customer_ID'].unique()

# %%
print(len(cst))
# Out:
# 5270

# %%
print(income_data['Income'].max())
# Out:
# 4999896.0

# %%
data['Gender']=data['Gender'].fillna('Unknown')

# %%
credit_data=data.groupby('Customer_ID')['Credit_Score'].max().reset_index()

# %%
print(credit_data)
# Out:
#      Customer_ID  Credit_Score
# 0       CUST1000         781.0
# 1       CUST1001         660.0
# 2       CUST1003         824.0
# 3       CUST1004         558.0
# 4       CUST1005         439.0
# ...          ...           ...
# 5264    CUST9993         682.0
# 5265    CUST9995         359.0
# 5266    CUST9996         816.0
# 5267    CUST9998         600.0
# 5268    CUST9999         694.0
#
# [5269 rows x 2 columns]
