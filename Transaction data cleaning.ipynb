# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Transaction_updated.csv')

# %%
data.head()
# Out:
#   Transaction_ID Customer_ID      Branch Transaction_Date Transaction_Type  \
# 0      TXN833420    CUST2665  TRIVANDRUM       2023-01-07          DEPOSIT
# 1      TXN659381    CUST9640     CHENNAI       2019-01-12       WITHDRAWAL
# 2      TXN880101    CUST3248     CALICUT       2018-01-16       WITHDRAWAL
# 3      TXN823601    CUST2120       KOCHI       18-12-2020       WITHDRAWAL
# 4      TXN318577    CUST2707  TRIVANDRUM       09/20/2021       WITHDRAWAL
#
#       Amount Currency   Status  Amount_in_INR
# 0   389650.0      INR  UNKNOWN       389650.0
# 1  3793001.0      USD  PENDING    314819083.0
# 2  2160839.0      INR  UNKNOWN      2160839.0
# 3  1180522.0      USD  SUCCESS     97983326.0
# 4  4326846.0      INR  PENDING      4326846.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15000 entries, 0 to 15088
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    15000 non-null  object
#  1   Customer_ID       15000 non-null  object
#  2   Branch            15000 non-null  object
#  3   Transaction_Date  15000 non-null  object
#  4   Transaction_Type  15000 non-null  object
#  5   Amount            15000 non-null  float64
#  6   Currency          15000 non-null  object
#  7   Status            15000 non-null  object
#  8   Amount_in_INR     15000 non-null  float64
# dtypes: float64(2), object(7)
# memory usage: 1.1+ MB

# %%
data=data.dropna()

# %%
data['Currency'].isna().sum()
# Out:
# 3070

# %%
data['Currency']=data['Currency'].fillna('INR')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15089 entries, 0 to 15088
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    15000 non-null  object
#  1   Customer_ID       15000 non-null  object
#  2   Branch            15000 non-null  object
#  3   Transaction_Date  15000 non-null  object
#  4   Transaction_Type  15000 non-null  object
#  5   Amount            15000 non-null  float64
#  6   Currency          15089 non-null  object
#  7   Status            11891 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 943.2+ KB

# %%
#Handling word case
data['Currency']=data['Currency'].str.strip().str.upper()

# %%
data['Branch']=data['Branch'].str.upper()

# %%
data['Transaction_Type']=data['Transaction_Type'].str.upper()

# %%
data.head(10)
# Out:
#   Transaction_ID Customer_ID       Branch Transaction_Date Transaction_Type  \
# 0      TXN833420    CUST2665   TRIVANDRUM       2023-01-07          DEPOSIT
# 1      TXN659381    CUST9640      CHENNAI       2019-01-12       WITHDRAWAL
# 2      TXN880101    CUST3248      CALICUT       2018-01-16       WITHDRAWAL
# 3      TXN823601    CUST2120        KOCHI       18-12-2020       WITHDRAWAL
# 4      TXN318577    CUST2707   TRIVANDRUM       09/20/2021       WITHDRAWAL
# 5      TXN446049    CUST2365  TRIVANDRUM        2020-06-06          DEPOSIT
# 6      TXN703245    CUST9399      CHENNAI       07/19/2024          DEPOSIT
# 7      TXN182215    CUST5534      CHENNAI       2021-12-27         TRANSFER
# 8      TXN318581    CUST7114        KOCHI       19-09-2023       WITHDRAWAL
# 9      TXN381025    CUST8176        KOCHI       28-12-2023       WITHDRAWAL
#
#       Amount Currency   Status
# 0   389650.0      INR      NaN
# 1  3793001.0      USD  PENDING
# 2  2160839.0      INR      NaN
# ...

# %%
#Convert USD to INR
conversion_rate={'INR':1,'USD':83}

data['Amount_in_INR']=data.apply(lambda row: row['Amount']*conversion_rate[row['Currency']],axis=1)

# %%
data.head(10)
# Out:
#   Transaction_ID Customer_ID       Branch Transaction_Date Transaction_Type  \
# 0      TXN833420    CUST2665   TRIVANDRUM       2023-01-07          DEPOSIT
# 1      TXN659381    CUST9640      CHENNAI       2019-01-12       WITHDRAWAL
# 2      TXN880101    CUST3248      CALICUT       2018-01-16       WITHDRAWAL
# 3      TXN823601    CUST2120        KOCHI       18-12-2020       WITHDRAWAL
# 4      TXN318577    CUST2707   TRIVANDRUM       09/20/2021       WITHDRAWAL
# 5      TXN446049    CUST2365  TRIVANDRUM        2020-06-06          DEPOSIT
# 6      TXN703245    CUST9399      CHENNAI       07/19/2024          DEPOSIT
# 7      TXN182215    CUST5534      CHENNAI       2021-12-27         TRANSFER
# 8      TXN318581    CUST7114        KOCHI       19-09-2023       WITHDRAWAL
# 9      TXN381025    CUST8176        KOCHI       28-12-2023       WITHDRAWAL
#
#       Amount Currency   Status  Amount_in_INR
# 0   389650.0      INR      NaN       389650.0
# ...

# %%
data['Status'].isna().sum()
# Out:
# 3198

# %%
print((3198/15000)*100)
# Out:
# 21.32

# %%
#Handling missing values in status
data['Status']=data['Status'].fillna('Unknown')

# %%
#Handling word case
data['Status']=data['Status'].str.strip().str.upper()

# %%
data.head(20)
# Out:
#    Transaction_ID Customer_ID       Branch Transaction_Date Transaction_Type  \
# 0       TXN833420    CUST2665   TRIVANDRUM       2023-01-07          DEPOSIT
# 1       TXN659381    CUST9640      CHENNAI       2019-01-12       WITHDRAWAL
# 2       TXN880101    CUST3248      CALICUT       2018-01-16       WITHDRAWAL
# 3       TXN823601    CUST2120        KOCHI       18-12-2020       WITHDRAWAL
# 4       TXN318577    CUST2707   TRIVANDRUM       09/20/2021       WITHDRAWAL
# 5       TXN446049    CUST2365  TRIVANDRUM        2020-06-06          DEPOSIT
# 6       TXN703245    CUST9399      CHENNAI       07/19/2024          DEPOSIT
# 7       TXN182215    CUST5534      CHENNAI       2021-12-27         TRANSFER
# 8       TXN318581    CUST7114        KOCHI       19-09-2023       WITHDRAWAL
# 9       TXN381025    CUST8176        KOCHI       28-12-2023       WITHDRAWAL
# 10      TXN562916    CUST3481      CHENNAI       18-10-2021          DEPOSIT
# ...

# %%
data.to_csv('E:\Data analysis\Project\Loan\Transaction_updated.csv',index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15236\3913322841.py:1: SyntaxWarning: invalid escape sequence '\D'
#   data.to_csv('E:\Data analysis\Project\Loan\Transaction_updated.csv',index=False)

# %%
#Convert into datetime

#data['Transaction_Date']=pd.to_datetime(data['Transaction_Date'],errors='coerce',dayfirst=True)

#convert into standardize into one format

#data['Transaction_date']=data['Transaction_Date'].dt.strftime('%Y-%m-%d')

# %%
data.head()
# Out:
#   Transaction_ID Customer_ID      Branch Transaction_Date Transaction_Type  \
# 0      TXN833420    CUST2665  TRIVANDRUM       2023-01-07          DEPOSIT
# 1      TXN659381    CUST9640     CHENNAI       2019-01-12       WITHDRAWAL
# 2      TXN880101    CUST3248     CALICUT       2018-01-16       WITHDRAWAL
# 3      TXN823601    CUST2120       KOCHI       18-12-2020       WITHDRAWAL
# 4      TXN318577    CUST2707  TRIVANDRUM       09/20/2021       WITHDRAWAL
#
#       Amount Currency   Status  Amount_in_INR
# 0   389650.0      INR  UNKNOWN       389650.0
# 1  3793001.0      USD  PENDING    314819083.0
# 2  2160839.0      INR  UNKNOWN      2160839.0
# 3  1180522.0      USD  SUCCESS     97983326.0
# 4  4326846.0      INR  PENDING      4326846.0

# %%
from datetime import datetime

def parse_date(x):
    for fmt in('%Y-%m-%d','%d-%m-%Y','%m/%d/%Y'):
        try:
            return datetime.strptime(x, fmt)
        except ValueError:
            continue
    return pd.NaT

data1['Transaction_Date']=data1['Transaction_Date'].apply(parse_date)


data1['Transaction_Date']=data1['Transaction_Date'].dt.strftime('%Y-%m-%d')

# %%
data.head(30)
# Out:
#    Transaction_ID Customer_ID       Branch Transaction_Date Transaction_Type  \
# 0       TXN833420    CUST2665   TRIVANDRUM       2023-01-07          DEPOSIT
# 1       TXN659381    CUST9640      CHENNAI       2019-01-12       WITHDRAWAL
# 2       TXN880101    CUST3248      CALICUT       2018-01-16       WITHDRAWAL
# 3       TXN823601    CUST2120        KOCHI       2020-12-18       WITHDRAWAL
# 4       TXN318577    CUST2707   TRIVANDRUM       2021-09-20       WITHDRAWAL
# 5       TXN446049    CUST2365  TRIVANDRUM        2020-06-06          DEPOSIT
# 6       TXN703245    CUST9399      CHENNAI       2024-07-19          DEPOSIT
# 7       TXN182215    CUST5534      CHENNAI       2021-12-27         TRANSFER
# 8       TXN318581    CUST7114        KOCHI       2023-09-19       WITHDRAWAL
# 9       TXN381025    CUST8176        KOCHI       2023-12-28       WITHDRAWAL
# 10      TXN562916    CUST3481      CHENNAI       2021-10-18          DEPOSIT
# ...

# %%
data.to_csv('E:/Data Analysis/Project/Loan/Transactn1.csv',index=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15000 entries, 0 to 15088
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    15000 non-null  object
#  1   Customer_ID       15000 non-null  object
#  2   Branch            15000 non-null  object
#  3   Transaction_Date  15000 non-null  object
#  4   Transaction_Type  15000 non-null  object
#  5   Amount            15000 non-null  float64
#  6   Currency          15000 non-null  object
#  7   Status            15000 non-null  object
#  8   Amount_in_INR     15000 non-null  float64
# dtypes: float64(2), object(7)
# memory usage: 1.1+ MB

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        15000 non-null  int64
#  1   Transaction_ID    15000 non-null  object
#  2   Customer_ID       15000 non-null  object
#  3   Branch            15000 non-null  object
#  4   Transaction_Date  15000 non-null  object
#  5   Transaction_Type  15000 non-null  object
#  6   Amount            15000 non-null  float64
#  7   Currency          15000 non-null  object
#  8   Status            15000 non-null  object
#  9   Amount_in_INR     15000 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 1.1+ MB

# %%
data1=pd.read_csv('Transactn1.csv')

# %%
data1['Status']=data1['Status'].str.strip().str.upper()

# %%
data1['Currency']=data1['Currency'].str.strip().str.upper()

# %%
data1['Transaction_Type']=data1['Transaction_Type'].str.strip().str.upper()

# %%
data1['Branch']=data1['Branch'].str.strip().str.upper()

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        15000 non-null  int64
#  1   Transaction_ID    15000 non-null  object
#  2   Customer_ID       15000 non-null  object
#  3   Branch            15000 non-null  object
#  4   Transaction_Date  15000 non-null  object
#  5   Transaction_Type  15000 non-null  object
#  6   Amount            15000 non-null  float64
#  7   Currency          15000 non-null  object
#  8   Status            15000 non-null  object
#  9   Amount_in_INR     15000 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 1.1+ MB

# %%
data1.to_csv(r'E:\Data Analysis\Project\Loan\Transactn1.csv',index=False)

# %%
data1=data1.drop(columns=['Unnamed: 0'])

# %%
data1['Transaction_Date']=pd.to_datetime(data1['Transaction_Date'])

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    15000 non-null  object
#  1   Customer_ID       15000 non-null  object
#  2   Branch            15000 non-null  object
#  3   Transaction_Date  15000 non-null  datetime64[ns]
#  4   Transaction_Type  15000 non-null  object
#  5   Amount            15000 non-null  float64
#  6   Currency          15000 non-null  object
#  7   Status            15000 non-null  object
#  8   Amount_in_INR     15000 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(6)
# memory usage: 1.0+ MB

# %%
data1.head(20)
# Out:
#    Transaction_ID Customer_ID      Branch Transaction_Date Transaction_Type  \
# 0       TXN833420    CUST2665  TRIVANDRUM       2023-01-07          DEPOSIT
# 1       TXN659381    CUST9640     CHENNAI       2019-01-12       WITHDRAWAL
# 2       TXN880101    CUST3248     CALICUT       2018-01-16       WITHDRAWAL
# 3       TXN823601    CUST2120       KOCHI       2020-12-18       WITHDRAWAL
# 4       TXN318577    CUST2707  TRIVANDRUM       2021-09-20       WITHDRAWAL
# 5       TXN446049    CUST2365  TRIVANDRUM       2020-06-06          DEPOSIT
# 6       TXN703245    CUST9399     CHENNAI       2024-07-19          DEPOSIT
# 7       TXN182215    CUST5534     CHENNAI       2021-12-27         TRANSFER
# 8       TXN318581    CUST7114       KOCHI       2023-09-19       WITHDRAWAL
# 9       TXN381025    CUST8176       KOCHI       2023-12-28       WITHDRAWAL
# 10      TXN562916    CUST3481     CHENNAI       2021-10-18          DEPOSIT
# ...
